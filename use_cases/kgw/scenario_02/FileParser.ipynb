# %%
import pandas as pd
import copy

# %%
#old_file = pd.read_csv('old_structure/resultFile.csv', header = None)
#old_file

import csv
with open ('old_structure/resultFile.csv', newline='') as csvfile:
    data = list(csv.reader(csvfile))
# Data is a list object
#data

# %%
i = 0
validation = 0
rowcounter = 0

yearcounter = int(data[0][0][5:])
blockcounter = 0
linecounter = 0
newdatabase = []
while i < len(data):
    if(data[i][0] == 'Housing costs by income group'):
        validation = 1
        linecounter = 0
        
        i=i+1 
    else:
        if(data[i][0] == 'jobByRegion'):
            validation = 0
            yearcounter = yearcounter + 1
        if(validation == 1):
            if(linecounter ==0):
                linecounter = linecounter + 1
                header = data[i]
                header.insert(0,'year')
            else:
                data[i].insert(0, yearcounter)
                newdatabase.append(data[i])
        i=i+1

dataframe = pd.DataFrame(newdatabase, columns = header)
dataframe
    
#dataframe.to_csv('hhRentAndIncome.csv', index = False)
# Out:
#      year  Income rent_250 rent_500 rent_750 rent_1000 rent_1250 rent_1500  \
# 0    2011   10000     1863     5978     3696      1455       486       182
# 1    2011   20000     2608    11035     8939      4881      1595       610
# 2    2011   30000     1386     8270     6218      4408      1970       737
# 3    2011   40000      731     4975     3405      2676      1440       654
# 4    2011   50000      374     3357     1989      1483      1044       482
# 5    2011   60000      212     2021     1114       966       671       375
# 6    2011   70000       92     1068      610       462       305       209
# 7    2011   80000       45      643      292       249       178       124
# 8    2011   90000       50      394      179       158       107        71
# 9    2011  100000       68      709      438       341       253       157
# 10   2012   10000     1839     6200     4019      1812       581       238
# 11   2012   20000     2660    10556     8260      4875      1676       627
# 12   2012   30000     1485     8079     6014      4205      1966       821
# 13   2012   40000      861     5024     3545      2681      1414       723
# 14   2012   50000      445     3192     2043      1548       953       531
# 15   2012   60000      247     2053     1167       955       671       385
# 16   2012   70000      115     1056      647       478       315       215
# 17   2012   80000       73      584      296       246       185       114
# 18   2012   90000       46      366      182       153       103        66
# 19   2012  100000       75      673      443       335       235       156
# 20   2013   10000     1842     6426     4232      1971       695       288
# 21   2013   20000     2620    10103     7891      4609      1708       659
# 22   2013   30000     1571     7902     5874      4047      1905       813
# 23   2013   40000      927     5075     3588      2661      1483       681
# 24   2013   50000      502     3238     2116      1633       984       507
# 25   2013   60000      272     2039     1269       975       662       374
# 26   2013   70000      139     1068      698       495       363       199
# 27   2013   80000       87      600      328       252       191       133
# 28   2013   90000       56      387      192       150       107        62
# 29   2013  100000       81      663      459       357       217       156
# ..    ...     ...      ...      ...      ...       ...       ...       ...
# 360  2047   10000     6553     2052     3952      3531      2561      1707
# 361  2047   20000     6084     1766     3443      3170      2440      1904
# 362  2047   30000     4359     1172     2496      2671      2366      1946
# 363  2047   40000     3359      852     1893      2012      1908      1677
# 364  2047   50000     2009      544     1143      1364      1424      1184
# 365  2047   60000     1399      352      798       903       913       919
# 366  2047   70000      703      176      414       467       496       514
# 385       790       655       530      3133        2225
# 386       443       395       293      1907        2392
# 387       215       166       141       946        2378
# 388       114       106        70       479        2502
# 389       128       111        78       466        2194
#
# [390 rows x 13 columns]

# %%
def siloOutputParser(startpoint, endpoint, databasename, ignoreFirstLine, ignoreHeader):
    
    ## Starting values
    i = 0
    parserData = copy.deepcopy(data)
    yearcounter = int(parserData[0][0][5:])
    linecounter = 0
    blockcounter = 0
    newdatabase = []
    validation = 0
    ## Parser loop
    
    while i < len(parserData):
        if(ignoreHeader == False):
            if(parserData[i][0] == startpoint):
                validation = 1
                linecounter = 0
                if(ignoreFirstLine == False):
                    header = parserData[i]
                    header.insert(0,'year')
                i=i+1
            else:
                if(parserData[i][0] == endpoint):
                    validation = 0
                    yearcounter = yearcounter + 1
                if(validation == 1):
                    if(linecounter == 0):
                        linecounter = linecounter + 1
                        if(ignoreFirstLine == True):
                            header = parserData[i]
                            header.insert(0,'year')
                        else:
                            parserData[i].insert(0, yearcounter)
                            newdatabase.append(parserData[i])                           
                    else:
                        parserData[i].insert(0, yearcounter)
                        newdatabase.append(parserData[i])
                i=i+1
            
        else:
            if(parserData[i][0] == startpoint):
                validation = 1
                linecounter = 0
            if(parserData[i][0] == endpoint):
                validation = 0
                yearcounter = yearcounter +1
            if(validation == 1):
                if(ignoreFirstLine == True):
                    if(linecounter >0):
                        parserData[i].insert(0, yearcounter)
                        newdatabase.append(parserData[i])
                else:
                    parserData[i].insert(0, yearcounter)
                    newdatabase.append(parserData[i])
                linecounter = linecounter + 1
            i=i+1
    #return dataframe
    if(ignoreHeader == False):
        dataframe = pd.DataFrame(newdatabase, columns = header)
    else:
        dataframe = pd.DataFrame(newdatabase)
    dataframe.to_csv(databasename, index = False)

# %%
siloOutputParser('Housing costs by income group','jobByRegion','hhRentAndIncome.csv',True, False)

# %%
siloOutputParser('ppByRace','hhByType','persByRace.csv',False, False)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-7-1376792beca1> in <module>()
# ----> 1 siloOutputParser('ppByRace','hhByType','persByRace.csv',False, False)
#
# <ipython-input-5-9cfe8c32c075> in siloOutputParser(startpoint, endpoint, databasename, ignoreFirstLine, ignoreHeader)
#      57     #return dataframe
#      58     if(ignoreHeader == False):
# ---> 59         dataframe = pd.DataFrame(newdatabase, columns = header)
#      60     else:
#      61         dataframe = pd.DataFrame(newdatabase)
#
# UnboundLocalError: local variable 'header' referenced before assignment

# %%
siloOutputParser('InmigrantsPP','Count of simulated events','persMigrants.csv',False, True)

# %%
siloOutputParser('aveCommuteDistByRegion','carOwnershipLevel','regionAvCommutingTime.csv',False, False)

# %%
siloOutputParser('Available land for construction by region','Housing costs by income group','regionAvailableLand.csv',True, True)

# %%
siloOutputParser('QualityLevel','CountOfDD','dwellingQualityLevel.csv',False, False)

# %%
siloOutputParser('jobByRegion','InmigrantsPP','jobsBySectorAndRegion.csv',False, False)
