# %%
import pandas as pd
import copy

# %%
#old_file = pd.read_csv('old_structure/resultFile.csv', header = None)
#old_file

import csv
with open ('old_structure/resultFile.csv', newline='') as csvfile:
    data = list(csv.reader(csvfile))

# Data is a list object
#data

# %%
#i = 0
#validation = 0
#rowcounter = 0

#yearcounter = int(data[0][0][5:])
#blockcounter = 0
#linecounter = 0
#newdatabase = []
#while i < len(data):
#    if(data[i][0] == 'Housing costs by income group'):
#        validation = 1
#        linecounter = 0
#        
#        i=i+1 
##    else:
#        if(data[i][0] == 'jobByRegion'):
#            validation = 0
#            yearcounter = yearcounter + 1
#        if(validation == 1):
#            if(linecounter ==0):
#                linecounter = linecounter + 1
#                header = data[i]
#                header.insert(0,'year')
#            else:
#                data[i].insert(0, yearcounter)
#                newdatabase.append(data[i])
#        i=i+1
#
#dataframe = pd.DataFrame(newdatabase, columns = header)
#dataframe
    
#dataframe.to_csv('hhRentAndIncome.csv', index = False)

# %%
def siloOutputParser(startpoint, endpoint, databasename, ignoreFirstLine, ignoreHeader):
    
    ## Starting values
    i = 0
    parserData = copy.deepcopy(data)
    yearcounter = int(parserData[0][0][5:])
    linecounter = 0
    blockcounter = 0
    newdatabase = []
    validation = 0
    ## Parser loop
    
    while i < len(parserData):
        if(ignoreHeader == False):
            if(parserData[i][0] == startpoint):
                validation = 1
                linecounter = 0
                if(ignoreFirstLine == False):
                    header = parserData[i]
                    header.insert(0,'year')
                i=i+1
            else:
                if(parserData[i][0] == endpoint):
                    if(validation == 1):
                        validation = 0
                        yearcounter = yearcounter + 1
                if(validation == 1):
                    if(linecounter == 0):
                        linecounter = linecounter + 1
                        if(ignoreFirstLine == True):
                            header = parserData[i]
                            header.insert(0,'year')
                        else:
                            parserData[i].insert(0, yearcounter)
                            newdatabase.append(parserData[i]) 
                            
                    else:
                        parserData[i].insert(0, yearcounter)
                        newdatabase.append(parserData[i])
                i=i+1
            
        else:
            if(parserData[i][0] == startpoint):
                validation = 1
                linecounter = 0
            if(parserData[i][0] == endpoint):
                validation = 0
                yearcounter = yearcounter +1
            if(validation == 1):
                if(ignoreFirstLine == True):
                    if(linecounter >0):
                        parserData[i].insert(0, yearcounter)
                        newdatabase.append(parserData[i])
                else:
                    parserData[i].insert(0, yearcounter)
                    newdatabase.append(parserData[i])
                linecounter = linecounter + 1
            i=i+1
    #return dataframe
    if(ignoreHeader == False):
        dataframe = pd.DataFrame(newdatabase, columns = header)
    else:
        dataframe = pd.DataFrame(newdatabase)
    dataframe.to_csv(databasename, index = False)

# %%
siloOutputParser('Housing costs by income group','jobByRegion','hhRentAndIncome.csv',True, False)

# %%
siloOutputParser('ppByRace','hhByType','persByRace.csv',False, False)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-9-258b27b6a6b3> in <module>
# ----> 1 siloOutputParser('ppByRace','hhByType','persByRace.csv',False, False)
#
# <ipython-input-7-2e22fb798e65> in siloOutputParser(startpoint, endpoint, databasename, ignoreFirstLine, ignoreHeader)
#      59     #return dataframe
#      60     if(ignoreHeader == False):
# ---> 61         dataframe = pd.DataFrame(newdatabase, columns = header)
#      62     else:
#      63         dataframe = pd.DataFrame(newdatabase)
#
# UnboundLocalError: local variable 'header' referenced before assignment

# %%
siloOutputParser('InmigrantsPP','Count of simulated events','persMigrants.csv',False, True)

# %%
siloOutputParser('aveCommuteDistByRegion','carOwnershipLevel','regionAvCommutingTime.csv',False, False)

# %%
siloOutputParser('Available land for construction by region','Housing costs by income group','regionAvailableLand.csv',True, True)

# %%
siloOutputParser('QualityLevel','CountOfDD','dwellingQualityLevel.csv',False, False)
# Out:
# 2011
# 2011
# 2011
# 2011
# 2016
# 2016
# 2016
# 2016
# 2021
# 2021
# 2021
# 2021
# 2026
# 2026
# 2026
# 2026
# 2031
# 2031
# 2031
# 2031
# 2036
# 2036
# 2036
# 2036
# 2041
# 2041
# 2041
# 2041
# 2046
# 2046
# 2046
# 2046
# 2051
# 2051
# 2051
# 2051
# 2056
# 2056
# 2056
# 2056
# 2061
# 2061
# 2061
# 2061
# 2066
# 2066
# 2066
# 2066
# 2071
# 2071
# 2071
# 2071
# 2076
# 2076
# 2076
# 2076
# 2081
# 2081
# 2081
# 2081
# 2086
# 2086
# 2086
# 2086
# 2091
# 2091
# 2091
# 2091
# 2096
# 2096
# 2096
# 2096
# 2101
# 2101
# 2101
# 2101
# 2106
# 2106
# 2106
# 2106
# 2111
# 2111
# 2111
# 2111
# 2116
# 2116
# 2116
# 2116
# 2121
# 2121
# 2121
# 2121
# 2126
# 2126
# 2126
# 2126
# 2131
# 2131
# 2131
# 2131
# 2136
# 2136
# 2136
# 2136
# 2141
# 2141
# 2141
# 2141
# 2146
# 2146
# 2146
# 2146
# 2151
# 2151
# 2151
# 2151
# 2156
# 2156
# 2156
# 2156
# 2161
# 2161
# 2161
# 2161
# 2166
# 2166
# 2166
# 2166
# 2171
# 2171
# 2171
# 2171
# 2176
# 2176
# 2176
# 2176
# 2181
# 2181
# 2181
# 2181
# 2186
# 2186
# 2186
# 2186
# 2191
# 2191
# 2191
# 2191
# 2196
# 2196
# 2196
# 2196
# 2201
# 2201
# 2201
# 2201

# %%
siloOutputParser('jobByRegion','Count of simulated events','jobsBySectorAndRegion.csv',False, False)
